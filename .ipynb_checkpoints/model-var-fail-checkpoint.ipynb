# %%
# preliminaries

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

from sktime.classification.interval_based import TimeSeriesForestClassifier

# %%
import numpy as np
import pandas as pd

# load data and fix issues w original

weather = pd.read_csv('madweather.csv')
#del weather['Unnamed: 0']
weather.head()
#weather.dtypes
# Out:
#       DATE  PRCP  TAVG  TMAX  TMIN
# 0  1900-01  0.69  23.7  30.8  16.6
# 1  1900-02  1.26  13.0  21.5   4.5
# 2  1900-03  1.33  25.1  32.3  17.9
# 3  1900-04  1.31  48.0  57.8  38.3
# 4  1900-05  1.87  60.5  70.9  50.2

# %%
# change data from object to datetime
weather['DATE'] = pd.to_datetime(weather.DATE, format = '%Y/%m')
data = weather.drop(['DATE'], axis = 1)
data.index = pd.DatetimeIndex(weather.DATE).to_period('m')
data.head()
# Out:
#          PRCP  TAVG  TMAX  TMIN
# DATE
# 1900-01  0.69  23.7  30.8  16.6
# 1900-02  1.26  13.0  21.5   4.5
# 1900-03  1.33  25.1  32.3  17.9
# 1900-04  1.31  48.0  57.8  38.3
# 1900-05  1.87  60.5  70.9  50.2

# %%
# missing values
cols = data.columns

data = data.fillna(method="ffill")
data = data.iloc[0:,0:3]
data
# Out:
#          PRCP
# DATE
# 1900-01  0.69
# 1900-02  1.26
# 1900-03  1.33
# 1900-04  1.31
# 1900-05  1.87
# ...       ...
# 1974-09  0.54
# 1974-10  1.81
# 1974-11  1.59
# 1974-12  1.67
# 1975-01  1.60
#
# [5198 rows x 1 columns]

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# %%
data.head()
# Out:
#          PRCP  TAVG  TMAX
# DATE
# 1900-01  0.69  23.7  30.8
# 1900-02  1.26  13.0  21.5
# 1900-03  1.33  25.1  32.3
# 1900-04  1.31  48.0  57.8
# 1900-05  1.87  60.5  70.9

# %%
# split into test and train
train = data[:int(0.8*(len(data)))]
test = data[int(0.8*(len(data))):]

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
# select order of VAR model
data_differenced = train.diff().dropna()
model = VAR(data_differenced)
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)

x = model.select_order(maxlags=12)
x.summary()
#minimums occur at p=12
# Out:
# C:\Users\nicol\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c0e0d06a196c> in <module>
#       1 # select order of VAR model
#       2 data_differenced = train.diff().dropna()
# ----> 3 model = VAR(data_differenced)
#       4 for i in [1,2,3,4,5,6,7,8,9]:
#       5     result = model.fit(i)
#
# ~\miniconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in __init__(self, endog, exog, dates, freq, missing)
#     522         super(VAR, self).__init__(endog, exog, dates, freq, missing=missing)
#     523         if self.endog.ndim == 1:
# --> 524             raise ValueError("Only gave one variable to VAR")
#     525         self.neqs = self.endog.shape[1]
#     526         self.n_totobs = len(endog)
#
# ValueError: Only gave one variable to VAR

# %%
# train model with selected order
model_fitted = model.fit(12)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 29, Nov, 2021
# Time:                     12:08:30
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.81522
# Nobs:                     4145.00    HQIC:                   6.70570
# Log likelihood:          -31306.8    FPE:                    769.485
# AIC:                      6.64572    Det(Omega_mle):         749.241
# --------------------------------------------------------------------
# Results for equation PRCP
# ===========================================================================
#               coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------
# const            0
# L7.TMAX          0.129802         0.030194            4.299           0.000
# L8.PRCP         -0.151815         0.067013           -2.265           0.023
# L8.TAVG         -0.326300         0.028164          -11.586           0.000
# L8.TMAX          0.050314         0.029852            1.685           0.092
# L9.PRCP         -0.185228         0.064430           -2.875           0.004
# L9.TAVG         -0.344009         0.028020          -12.277           0.000
# L9.TMAX          0.124064         0.029914            4.147           0.000
# L10.PRCP        -0.048316         0.060409           -0.800           0.424
# L10.TAVG        -0.229237         0.028435           -8.062           0.000
# L10.TMAX         0.091669         0.030312            3.024           0.002
# L11.PRCP         0.112851         0.054279            2.079           0.038
# L11.TAVG        -0.125209         0.028179           -4.443           0.000
# L11.TMAX         0.144398         0.030142            4.791           0.000
# L12.PRCP         0.019673         0.042071            0.468           0.640
# L12.TAVG        -0.039049         0.027873           -1.401           0.161
# L12.TMAX         0.099519         0.029910            3.327           0.001
# ===========================================================================
#
# Results for equation TMAX
# ===========================================================================
#               coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------
# const           -0.016038         0.075189           -0.213           0.831
# L1.PRCP          0.007591         0.038942            0.195           0.845
# L1.TAVG         -0.037395         0.025918           -1.443           0.149
# L1.TMAX         -0.138009         0.027806           -4.963           0.000
# L2.PRCP          0.047117         0.050162            0.939           0.348
# L2.TAVG         -0.046924         0.026182           -1.792           0.073
# L2.TMAX         -0.038152         0.028004           -1.362           0.173
# L3.PRCP          0.078670         0.055726            1.412           0.158
# L3.TAVG         -0.016585         0.026411           -0.628           0.530
# L3.TMAX         -0.147368         0.028179           -5.230           0.000
# L4.PRCP          0.061485         0.059438            1.034           0.301
# L4.TAVG         -0.010980         0.026035           -0.422           0.673
# L4.TMAX         -0.213284         0.027785           -7.676           0.000
# L5.PRCP         -0.086473         0.061917           -1.397           0.163
# L5.TAVG         -0.037161         0.026164           -1.420           0.156
# L5.TMAX         -0.278860         0.027731          -10.056           0.000
# L6.PRCP         -0.085219         0.063481           -1.342           0.179
# L6.TAVG         -0.050554         0.026278           -1.924           0.054
# L6.TMAX         -0.263972         0.028023           -9.420           0.000
# L7.PRCP         -0.171422         0.063611           -2.695           0.007
# L7.TAVG         -0.033763         0.026282           -1.285           0.199
# L7.TMAX         -0.204914         0.028041           -7.308           0.000
# L8.PRCP         -0.141352         0.062235           -2.271           0.023
# L8.TAVG         -0.009252         0.026155           -0.354           0.724
# L8.TMAX         -0.262763         0.027723           -9.478           0.000
# L9.PRCP         -0.167882         0.059835           -2.806           0.005
# L9.TAVG         -0.012817         0.026022           -0.493           0.622
# L9.TMAX         -0.187777         0.027781           -6.759           0.000
# L10.PRCP        -0.003610         0.056102           -0.064           0.949
# L10.TAVG        -0.030608         0.026407           -1.159           0.246
# L10.TMAX        -0.080538         0.028151           -2.861           0.004
# L11.PRCP         0.095807         0.050408            1.901           0.057
# L11.TAVG        -0.024058         0.026169           -0.919           0.358
# L11.TMAX         0.073223         0.027992            2.616           0.009
# L12.PRCP         0.029061         0.039071            0.744           0.457
# L12.TAVG        -0.041309         0.025885           -1.596           0.111
# L12.TMAX         0.128090         0.027777            4.611           0.000
# ===========================================================================
#
# Correlation matrix of residuals
#             PRCP      TAVG      TMAX
# PRCP    1.000000  0.051343 -0.009031
# TAVG    0.051343  1.000000  0.827182
# TMAX   -0.009031  0.827182  1.000000

# %%
#check for serial correlation of residuals
def adjust(val, length= 6): return str(val).ljust(length)

from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_fitted.resid)

for col, val in zip(data.columns, out):
    print(adjust(col), ':', round(val, 2))

# no significant correlation
# Out:
# PRCP   : 2.01
# TAVG   : 2.0
# TMAX   : 2.0

# %%
prediction = model_fit.forecast(model_fit.y, steps = len(test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e04cb9a8357b> in <module>
# ----> 1 prediction = model_fit.forecast(model_fit.y, steps = len(test))
#
# NameError: name 'model_fit' is not defined

# %%
# dataframe of predictions
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,5):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

# %%
# check rmse
from sklearn.metrics import mean_squared_error
for i in cols:
    print('rmse value for', i, 'is : ', np.sqrt(mean_squared_error(test[i], pred[i])))
# Out:
# rmse value for PRCP is :  2.5875148554341263
# rmse value for SNOW is :  5.489238550905626
# rmse value for TAVG is :  20.230711134422
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\R-MINI~1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\R-MINI~1\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\R-MINI~1\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TMAX'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8680/1938685704.py in <module>
#       2 from sklearn.metrics import mean_squared_error
#       3 for i in cols:
# ----> 4     print('rmse value for', i, 'is : ', np.sqrt(mean_squared_error(test[i], pred[i])))
#
# ~\AppData\Local\R-MINI~1\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\R-MINI~1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'TMAX'

# %%
#final predictions
modelfin = VAR(endog=data)
modelfin_fit = modelfin.fit()
ypred = modelfin_fit.forecast(modelfin_fit.y, steps = 1)
print(ypred)
# Out:
# [[ 2.08015611  9.74504194 27.73572844]]
# C:\Users\nicol\AppData\Local\R-MINI~1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\nicol\AppData\Local\R-MINI~1\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
# evaluate a forecast in the format [chunk][variable][time]
def evaluate_forecasts(prediction, test):
	lead_times = get_lead_times()
	total_mae, times_mae = 0.0, [0.0 for _ in range(len(lead_times))]
	total_c, times_c = 0, [0 for _ in range(len(lead_times))]
	# enumerate test chunks
	for i in range(len(test_chunks)):
		# convert to forecasts
		actual = testset[i]
		predicted = predictions[i]
		# enumerate target variables
		for j in range(predicted.shape[0]):
			# enumerate lead times
			for k in range(len(lead_times)):
				# skip if actual in nan
				if isnan(actual[j, k]):
					continue
				# calculate error
				error = calculate_error(actual[j, k], predicted[j, k])
				# update statistics
				total_mae += error
				times_mae[k] += error
				total_c += 1
				times_c[k] += 1
	# normalize summed absolute errors
	total_mae /= total_c
	times_mae = [times_mae[i]/times_c[i] for i in range(len(times_mae))]
	return total_mae, times_mae

# %%
# summarize scores
def summarize_error(name, total_mae, times_mae):
	# print summary
	lead_times = get_lead_times()
	formatted = ['+%d %.3f' % (lead_times[i], times_mae[i]) for i in range(len(lead_times))]
	s_scores = ', '.join(formatted)
	print('%s: [%.3f MAE] %s' % (name, total_mae, s_scores))
	# plot summary
	pyplot.plot([str(x) for x in lead_times], times_mae, marker='.')
	pyplot.show()
